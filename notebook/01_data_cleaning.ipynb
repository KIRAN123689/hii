# %%
print("Notebook works")
# Out:
# Notebook works

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\suman\ipl\notebook

# %%
import os
os.chdir("..")
print(os.getcwd())
# Out:
# C:\Users\suman\ipl

# %%
import pandas as pd

ball = pd.read_csv("data/raw/ball_by_ball_data.csv")
matches = pd.read_csv("data/raw/matches.csv")

print("Ball-by-ball shape:", ball.shape)
print("Matches shape:", matches.shape)
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_2728\1873675716.py:4: DtypeWarning: Columns (28,29,30,31,43,46,47,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   matches = pd.read_csv("data/raw/matches.csv")
# Ball-by-ball shape: (278205, 30)
# Matches shape: (278205, 64)
